# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('supershops.csv.xlsx')

# %%
df2=df.copy()#store main value in different variable
df3=df.copy()
df4=df.copy()
df5=df.copy()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()#this fuction is use to find the how many null value here
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.dropna()
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.shape
# Out:
# (50, 5)

# %%
df.dropna().shape
# Out:
# (49, 5)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %% [markdown]
# # MinMaxScaler/Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
m = MinMaxScaler()

# %%
df['Marketing Spend'] = m.fit_transform(df[['Marketing Spend']]) # fit() = training the model ; transform() = replace the values

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
ad = m.fit(df[['Administration']])

# %%
ad
# Out:
# MinMaxScaler()

# %%
df.head()#no change
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df['Administration_Transform'] = m.transform(df[['Administration']])

# %%
df['Administration_Transform'].head()
# Out:
# 0    0.651744
# 1    0.761972
# 2    0.379579
# 3    0.512998
# 4    0.305328
# Name: Administration_Transform, dtype: float64

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
#
#    Administration_Transform
# 0                  0.651744
# 1                  0.761972
# 2                  0.379579
# 3                  0.512998
# 4                  0.305328

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
s = StandardScaler()

# %%
s
# Out:
# StandardScaler()

# %%
df2['Profit']=s.fit(df2[['Profit']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area            Profit  \
# 0        114523.61       136897.80  471784.10    Dhaka  StandardScaler()
# 1        162597.70       151377.59  443898.53      Ctg  StandardScaler()
# 2        153441.51       101145.55  407934.54  Rangpur  StandardScaler()
# 3        144372.41       118671.85  383199.62    Dhaka  StandardScaler()
# 4        142107.34        91391.77  366168.42  Rangpur  StandardScaler()
#
#    Transport_Transform
# 0             9.016584
# 1             8.317716
# 2             7.416388
# 3             6.796482
# 4             6.369646

# %%
s.mean_
# Out:
# array([112012.6392])

# %%
df2['Transport_Transform']=s.transform(df2[['Transport']])

# %%
df2['Transport_Transform'].head()
# Out:
# 0    9.016584
# 1    8.317716
# 2    7.416388
# 3    6.796482
# 4    6.369646
# Name: Transport_Transform, dtype: float64

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area            Profit  \
# 0        114523.61       136897.80  471784.10    Dhaka  StandardScaler()
# 1        162597.70       151377.59  443898.53      Ctg  StandardScaler()
# 2        153441.51       101145.55  407934.54  Rangpur  StandardScaler()
# 3        144372.41       118671.85  383199.62    Dhaka  StandardScaler()
# 4        142107.34        91391.77  366168.42  Rangpur  StandardScaler()
#
#    Transport_Transform
# 0             9.016584
# 1             8.317716
# 2             7.416388
# 3             6.796482
# 4             6.369646

# %% [markdown]
# # Max Absolute Scaler

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
M=MaxAbsScaler().fit(df3[['Profit']])

# %%
M
# Out:
# MaxAbsScaler()

# %%
df3['Profit_transform']=M.transform(df3[['Profit']])

# %%
df3['Profit_transform'].head()
# Out:
# 0    1.000000
# 1    0.997557
# 2    0.993699
# 3    0.951317
# 4    0.864383
# Name: Profit_transform, dtype: float64

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94
#
#    Profit_transform
# 0          1.000000
# 1          0.997557
# 2          0.993699
# 3          0.951317
# 4          0.864383

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
R=RobustScaler().fit(df4[['Marketing Spend']])

# %%
R
# Out:
# RobustScaler()

# %%
df4[['Marketing_Spend']]=R.transform(df4[['Marketing Spend']])

# %%
df4[['Marketing_Spend']].head()
# Out:
#    Marketing_Spend
# 0        -1.184606
# 1        -1.184593
# 2        -1.184596
# 3        -1.184598
# 4        -1.184598

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0         0.672530       136897.80  471784.10    Dhaka  192261.83
# 1         1.452113       151377.59  443898.53      Ctg  191792.06
# 2         1.303634       101145.55  407934.54  Rangpur  191050.39
# 3         1.156567       118671.85  383199.62    Dhaka  182901.99
# 4         1.119836        91391.77  366168.42  Rangpur  166187.94
#
#    Marketing_Spend
# 0        -1.184606
# 1        -1.184593
# 2        -1.184596
# 3        -1.184598
# 4        -1.184598

# %% [markdown]
# # Max

# %%
max_val = df5['Marketing Spend'].max()

# %%
max_val
# Out:
# 165349.2

# %%
df5['Marketing_Spend'] = df5['Marketing Spend'] / max_val

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94
#
#    Marketing_ Spend
# 0          0.000004
# 1          0.000006
# 2          0.000006
# 3          0.000005
# 4          0.000005
